# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("NucleosPoblacion.csv")
dataset.head()
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %% [markdown]
# # Parte 1: Numpy

# %% [markdown]
# ### 1. ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
a=np.arange(1,1001,1)
a.size
# Out:
# 1000

# %% [markdown]
# ### 2. Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
b=np.arange(2,100,2,)
b_dec = np.sort(b)[::-1]
b_dec [0:10]
# Out:
# array([98, 96, 94, 92, 90, 88, 86, 84, 82, 80])

# %% [markdown]
# ### 3. Dado el array
# 2 4 5 6
# 0 3 7 4
# 8 8 5 2
# 1 5 6 1
#
# ### Seleccione con una instrucción el subarray de elementos
# 0 3 7 4
#
# ### Después, seleccione el subarray de elementos
# 2 5
# 8 5

# %%
c=np.array([2,4,5,6,0,3,7,4,8,8,5,2,1,5,6,1])
c1=c[4:8]
print (c1)
# Out:
# [0 3 7 4]

# %%
sub=np.reshape(c,(2,8))
sub
# Out:
# array([[2, 4, 5, 6, 0, 3, 7, 4],
#        [8, 8, 5, 2, 1, 5, 6, 1]])

# %%
c2=sub[0,0],sub[0,2],sub[-1,0],sub[-1,2]
c2
# Out:
# (2, 5, 8, 5)

# %% [markdown]
# ### 4. Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b)

# %%
a4=np.array([1,4,2,7])
b4=np.array([1,3,2,9])
media=np.mean(a4-b4)
media
# Out:
# -0.25

# %% [markdown]
# ### 5. Tengo valores de cordenadas (x, y) en las columnas del array
# 1.33 4.5
#
# 30.0 10.7
#
# 70.2 0.5
# ### Agregue a este array las coordenadas (37.1, -3.6). Muestre en pantalla las dimensiones del nuevo array.

# %%
e={'X': [1.33,30.0,70.2],
    'Y':[4.5,10.7,0.5]
}
df=pd.DataFrame(e)
df
# Out:
#        X     Y
# 0   1.33   4.5
# 1  30.00  10.7
# 2  70.20   0.5

# %%
df.loc[3]={'X':37.1,'Y':-3.6}
df
# Out:
#        X     Y
# 0   1.33   4.5
# 1  30.00  10.7
# 2  70.20   0.5
# 3  37.10  -3.6

# %% [markdown]
# ### 6. Copie el array del ejercicio anterior. Traspóngalo (Agregue ahora dos nuevos pares de coordenadas: (10.8,3.0) y (35.8, 12.0)

# %%
df2=np.transpose(df)
df2
# Out:
#       0     1     2     3
# X  1.33  30.0  70.2  37.1
# Y  4.50  10.7   0.5  -3.6

# %%
df2['4']=[10.8,3.0]
df2['5']=[35.8,12.0]
df2
# Out:
#       0     1     2     3     4     5
# X  1.33  30.0  70.2  37.1  10.8  35.8
# Y  4.50  10.7   0.5  -3.6   3.0  12.0

# %% [markdown]
# # Parte 2: Exploración y Minería de Datos

# %%
dataset.head()
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %% [markdown]
# ### 1. ¿Cuántos Municipios tienen más de 100000 habitantes?

# %%
dataset[dataset['Poblacion']>100000]
# Out:
#      FID  OBJECTID                       Texto  Poblacion  CodMun  \
# 9      9        10  Las Palmas de Gran Canaria   383308.0   35016
# 16    16        17                       Telde   100900.0   35026
# 28    28        29  San Cristóbal de La Laguna   152222.0   38023
# 40    40        41      Santa Cruz de Tenerife   222643.0   38038
# 42    42        43                     Badajoz   150376.0    6015
# ..   ...       ...                         ...        ...     ...
# 683  683       684    Santa Coloma de Gramenet   120060.0    8245
# 689  689       690                    Terrassa   212724.0    8279
# 725  725       726                      Lleida   137387.0   25120
# 735  735       736                        Reus   106622.0   43123
# 737  737       738                   Tarragona   140184.0   43148
#
#                       Municipio  CodProvin               Provincia          X  \
# 9    Las Palmas de Gran Canaria         35              Las Palmas -15.413387
# ...

# %% [markdown]
# ### 2. Realice una gráfica de barras sobre la población de cada ciudad, ordenela de menor a mayo y responda:
# #### a. ¿Cuál es la segunda ciudad más poblada?
# #### b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
dataset_pob=dataset.sort_values('Poblacion',ascending=False, inplace=False)
dataset_pob
# Out:
#      FID  OBJECTID           Texto  Poblacion  CodMun       Municipio  \
# 355  355       356          Madrid  3273049.0   28079          Madrid
# 623  623       624       Barcelona  1619337.0    8019       Barcelona
# 561  561       562        Valencia   809267.0   46250        Valencia
# 492  492       493         Sevilla   704198.0   41091         Sevilla
# 591  591       592        Zaragoza   675121.0   50297        Zaragoza
# ..   ...       ...             ...        ...     ...             ...
# 525  525       526           Buñol    10077.0   46077           Buñol
# 746  746       747  Premià de Dalt    10064.0    8230  Premià de Dalt
# 168  168       169         Amurrio    10050.0    1002         Amurrio
# 115  115       116  Caldas de Reis    10045.0   36005  Caldas de Reis
# 307  307       308       Zumarraga    10037.0   20080       Zumarraga
#
#      CodProvin          Provincia         X          Y
# 355         28             Madrid -3.703797  40.416630
# ...

# %%
pob_prov=dataset.groupby(['Provincia'])['Poblacion'].sum().plot(kind='bar',
                                                       title='Poblacion por Provincia',
                                                       ylabel='Poblacion',
                                                       color = 'orange',
                                                       edgecolor ='black')
pob_prov
# Out:
# <AxesSubplot:title={'center':'Poblacion por Provincia'}, xlabel='Provincia', ylabel='Poblacion'>

# %% [markdown]
# #### a. ¿Cuál es la segunda ciudad más poblada? Respuesta: Barcelona
# #### b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas? Respuesta: 36

# %%
pob_prov=dataset.groupby(['Provincia'])['Poblacion'].sum()

# %%
rank=pob_prov.rank(numeric_only = True)
rank
# Out:
# Provincia
# A Coruña                  39.0
# Alacant/Alicante          49.0
# Albacete                  20.0
# Almería                   33.0
# Asturias                  40.0
# Badajoz                   24.0
# Barcelona                 51.0
# Burgos                    18.0
# Cantabria                 28.0
# Castelló/Castellón        31.0
# Ceuta                      7.0
# Ciudad Real               23.0
# Cuenca                     5.0
# Cáceres                   14.0
# Cádiz                     44.0
# Córdoba                   34.0
# Girona                    30.0
# Granada                   36.0
# Guadalajara               11.0
# Guipúzcoa                 32.0
# Huelva                    25.0
# Huesca                    10.0
# Illes Balears             43.0
# Jaén                      27.0
# La Rioja                  17.0
# Las Palmas                45.0
# León                      21.0
# Lleida                    16.0
# Lugo                      13.0
# ...

# %% [markdown]
# ### 3. ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.

# %%
dataset[(dataset['Provincia']=='Extremadura')&
        (dataset['Poblacion']>5000)]
# Out:
# Empty DataFrame
# Columns: [FID, OBJECTID, Texto, Poblacion, CodMun, Municipio, CodProvin, Provincia, X, Y]
# Index: []

# %%
dataset['Provincia'].unique()
# Out:
# array(['Las Palmas', 'Santa Cruz de Tenerife', 'Badajoz', 'Cáceres',
#        'Cádiz', 'A Coruña', 'Huelva', 'León', 'Lugo', 'Ourense',
#        'Asturias', 'Pontevedra', 'Salamanca', 'Sevilla', 'Albacete',
#        'Alacant/Alicante', 'Álava', 'Almería', 'Ávila', 'Burgos',
#        'Castelló/Castellón', 'Ciudad Real', 'Córdoba', 'Cuenca',
#        'Granada', 'Guadalajara', 'Guipúzcoa', 'Huesca', 'Jaén',
#        'La Rioja', 'Madrid', 'Málaga', 'Murcia', 'Navarra', 'Palencia',
#        'Cantabria', 'Segovia', 'Soria', 'Teruel', 'Toledo',
#        'València/Valencia', 'Valladolid', 'Vizcaya', 'Zamora', 'Zaragoza',
#        'Ceuta', 'Illes Balears', 'Barcelona', 'Girona', 'Lleida',
#        'Tarragona', 'Melilla'], dtype=object)

# %% [markdown]
# ### 4. ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
Norte=dataset[['Municipio','Provincia','Poblacion','Y']]
Norte1=Norte.sort_values('Y',ascending=False)
Norte1.head(1)
# Out:
#     Municipio Provincia  Poblacion          Y
# 104   Viveiro      Lugo    16211.0  43.625578

# %% [markdown]
# ### 5. Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada

# %%
data_granada=dataset[dataset['Provincia']=='Granada']
data_granada.describe()
# Out:
#              FID   OBJECTID      Poblacion        CodMun  CodProvin  \
# count   20.00000   20.00000      20.000000     20.000000       20.0
# mean   275.50000  276.50000   30217.850000  18140.900000       18.0
# std      5.91608    5.91608   50355.491715    189.385961        0.0
# min    266.00000  267.00000   10386.000000  18003.000000       18.0
# 25%    270.75000  271.75000   13146.500000  18052.250000       18.0
# 50%    275.50000  276.50000   17526.000000  18112.000000       18.0
# 75%    280.25000  281.25000   21739.750000  18154.250000       18.0
# max    285.00000  286.00000  239154.000000  18905.000000       18.0
#
#                X          Y
# count  20.000000  20.000000
# mean   -3.606477  37.139321
# std     0.266746   0.191057
# min    -4.152187  36.734414
# 25%    -3.689279  37.131378
# 50%    -3.631257  37.171351
# 75%    -3.587665  37.230955
# max    -2.774856  37.490778

# %% [markdown]
# ### 6. Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
pob_prov=dataset[['Municipio','Provincia','Poblacion']]
pob_prov

pobl=np.transpose(pob_prov)
pobl
# Out:
#                   0           1           2           3           4    \
# Municipio     Agüimes     Antigua    Arrecife      Arucas      Gáldar
# Provincia  Las Palmas  Las Palmas  Las Palmas  Las Palmas  Las Palmas
# Poblacion     29431.0     10458.0     58156.0     36745.0     24473.0
#
#                   5           6           7           8    \
# Municipio     Ingenio       Mogán    La Oliva      Pájara
# Provincia  Las Palmas  Las Palmas  Las Palmas  Las Palmas
# Poblacion     29640.0     22638.0     22351.0     20622.0
#
#                                   9    ...      842      843      844  \
# Municipio  Las Palmas de Gran Canaria  ...    Mijas    Lorca    Lorca
# Provincia                  Las Palmas  ...   Málaga   Murcia   Murcia
# Poblacion                    383308.0  ...  15136.0  12790.0  11905.0
#
#                845      846      847      848      849      850  \
# Municipio    Lorca   Murcia   Murcia   Murcia   Murcia   Toledo
# ...

# %%
for Provincia in Poblacion:
    print("-----------------------")
    print(Provincia)
    estadisticos=pob_prov[Provincia].describe()
    sns.displot(Poblacion, x='Poblacion', kind='hist')
    plt.show()
# Out:
# -----------------------
# Municipio
# -----------------------
# Provincia
# -----------------------
# Poblacion

# %% [markdown]
# ### 7. Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
Municipios=dataset[['Municipio','Poblacion']]
Mun50=Municipios.sample(frac = 0.06, random_state = 18)
Mun50
# Out:
#                       Municipio  Poblacion
# 346            Collado Villalba    59900.0
# 677    Sant Joan de Vilatorrada    10856.0
# 572                     Durango    28261.0
# 281                Pinos Puente    13421.0
# 414      Fuente Álamo de Murcia    15193.0
# 682        Sant Sadurní d'Anoia    12323.0
# 502                        Mora    10516.0
# 276                        Loja    21688.0
# 259       Peñarroya-Pueblonuevo    11814.0
# 83                    Aljaraque    18443.0
# 212             Aranda de Duero    33154.0
# 618                      Sóller    14075.0
# 80                  Santa Comba    10408.0
# 129                        Poio    16309.0
# 516                   L'Alcúdia    11246.0
# 75                        Ordes    12868.0
# 284                    La Zubia    18240.0
# 96                      Astorga    12015.0
# 194                  Torrevieja   101091.0
# 0                       Agüimes    29431.0
# 63                     Betanzos    13673.0
# ...

# %%
Mun50.describe()
# Out:
#            Poblacion
# count      51.000000
# mean    33908.470588
# std     50861.366439
# min     10408.000000
# 25%     12874.500000
# 50%     19143.000000
# 75%     28142.500000
# max    334418.000000

# %% [markdown]
# ### 8. Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero.

# %%
Distancia=dataset[['Municipio','Provincia','Y']]
Distancia[Dis_Madrid]=Distancia.apply(lambda x:x['Y']-40.416630,axis=1)
Distancia.head(5)
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_10304\1902359100.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Distancia[Dis_Madrid]=Distancia.apply(lambda x:x['Y']-40.416630,axis=1)
#   Municipio   Provincia          Y          0
# 0   Agüimes  Las Palmas  27.900542 -12.516088
# 1   Antigua  Las Palmas  28.418966 -11.997664
# 2  Arrecife  Las Palmas  28.960649 -11.455981
# 3    Arucas  Las Palmas  28.117496 -12.299134
# 4    Gáldar  Las Palmas  28.143873 -12.272757

# %%
Cercano=Distancia.sort_values('Y',ascending=False, inplace=False)
Cercano.head(5)
# Out:
#       Municipio Provincia          Y         0
# 104     Viveiro      Lugo  43.625578  3.208948
# 447       Gozón  Asturias  43.614030  3.197400
# 443     Carreño  Asturias  43.590199  3.173569
# 444  Castrillón  Asturias  43.559984  3.143354
# 442      Avilés  Asturias  43.558577  3.141947

# %%
Cercano=Distancia.sort_values('Y',ascending=True, inplace=False)
Cercano.head(5)
# Out:
#                      Municipio   Provincia          Y          0
# 757  San Bartolomé de Tirajana  Las Palmas  27.770340 -12.646290
# 759    Santa Lucía de Tirajana  Las Palmas  27.832113 -12.584517
# 760    Santa Lucía de Tirajana  Las Palmas  27.841727 -12.574903
# 758    Santa Lucía de Tirajana  Las Palmas  27.856854 -12.559776
# 6                        Mogán  Las Palmas  27.880172 -12.536458
